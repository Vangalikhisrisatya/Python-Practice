# %%
set1={1,2,3,4,5}
set2={1,2,3,3,2,4,4,1}
print(set1)
print(set2)
# Out:
# {1, 2, 3, 4, 5}
# {1, 2, 3, 4}

# %%
set1=set([1,2,3,4,5])
print(set1)
# Out:
# {1, 2, 3, 4, 5}

# %%
mixed_set = {1, 'hello', (1, 2, 3)}
print (mixed_set)
# Out:
# {1, (1, 2, 3), 'hello'}

# %%
#Accessing set items
languages={"Telugu","Tamil","Hindi","Kannada","Malayalam"}
for i in languages:
    print(i)
# Out:
# Kannada
# Hindi
# Telugu
# Tamil
# Malayalam

# %%
#issubset
import itertools
s1={1,2,3,4,5}
print({1,2}.issubset(s1))
#Generating all subsets using 2 elements
subset_with_two_elements=[set(subset) for subset in itertools.combinations(s1,2)]
print(subset_with_two_elements)
# Out:
# True
# [{1, 2}, {1, 3}, {1, 4}, {1, 5}, {2, 3}, {2, 4}, {2, 5}, {3, 4}, {3, 5}, {4, 5}]

# %%
langs = {"C", "C++", "Java", "Python"}
if "Java" in langs:
    print("Java is present in the set.")
else:
    print("Java is not present in the set.")
if "SQL" not in langs:
    print("SQL is not present in the set.")
else:
    print("SQL is present in the set.")
# Out:
# Java is present in the set.
# SQL is not present in the set.

# %%
#add set items
langs = set()
langs.add("C#")
langs.add("C")
langs.add("C++")
langs.add("Python")
langs.add("Java")
print(langs)
# Out:
# {'C#', 'Python', 'C++', 'C', 'Java'}

# %%
#update method
langs.update({"SQL"})
print(langs)
# Out:
# {'C#', 'Python', 'C++', 'SQL', 'C', 'Java'}

# %%
langs.update(["Ruby"])
print(langs)
# Out:
# {'C#', 'Python', 'C++', 'SQL', 'Ruby', 'C', 'Java'}

# %%
lang1 = {"C", "C++", "Java", "Python"}
lang2 = {"PHP", "C#", "Perl"}
lang1.update(lang2)
print(lang1)
# Out:
# {'C#', 'C', 'Python', 'Java', 'C++', 'PHP', 'Perl'}

# %%
set1 = set("Hello")
set1.update("World")
print (set1)
# Out:
# {'r', 'd', 'l', 'H', 'W', 'e', 'o'}

# %%
#union
lang1 = {"C", "C++", "Java", "Python"}
lang2 = {"PHP", "C#", "Perl"}
lang3 = {"SQL", "C#"}
union1=lang1.union(lang2)
union2=lang2|lang3
print(union1)
print(union2)
# Out:
# {'C#', 'C', 'Python', 'Java', 'C++', 'PHP', 'Perl'}
# {'C#', 'PHP', 'Perl', 'SQL'}

# %%
#set comprehension
num={1,2,3,4,5,6}
set_comp={x**2 for x in num}
print(set_comp)
# Out:
# {1, 4, 36, 9, 16, 25}

# %%
for index,item in enumerate(num):
    print("Index:",index,"Item",item)
# Out:
# Index: 0 Item 1
# Index: 1 Item 2
# Index: 2 Item 3
# Index: 3 Item 4
# Index: 4 Item 5
# Index: 5 Item 6

# %%
#Removing elements
st1 = {"Maths", "Physics", 21, 69.75}
st1.remove("Physics")
print(st1)
# Out:
# {21, 'Maths', 69.75}

# %%
st1 = {"Maths", "Physics", 21, 69.75}
st1.remove("Chemistry") #key not present,raises a key error
print(st1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\LIKHIS~1\AppData\Local\Temp/ipykernel_30748/1670290432.py in <module>
#       1 st1 = {"Maths", "Physics", 21, 69.75}
# ----> 2 st1.remove("Chemistry") #key not present,raises a key error
#       3 print(st1)
#
# KeyError: 'Chemistry'

# %%
#discard
st1 = {"Maths", "Physics", 21, 69.75}
st1.discard("Physics")
print(st1)
st1.discard("Chemistry") #key not present,doesn't raise error
print(st1)
# Out:
# {'Maths', 69.75, 21}
# {'Maths', 69.75, 21}

# %%
set1={1,2,3,4,5}
rem=set1.pop()
print(rem)
print(set1)
# Out:
# 1
# {2, 3, 4, 5}

# %%
empty_set={}
prin=empty_set.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\LIKHIS~1\AppData\Local\Temp/ipykernel_30748/2992199045.py in <module>
#       1 empty_set={}
# ----> 2 prin=empty_set.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
#clear
set1={1,2,4,3,5,6}
clear=set1.clear()
print(set1)
# Out:
# set()

# %%
#difference
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}
s1.difference_update(s2)
print(s1-s2)
print(s1)
# Out:
# {1, 2, 3}
# {1, 2, 3}

# %%
#removes common elements
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}
res=s1^s2
print(res)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
#intersection update  -removes uncommon elements
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}
s1.intersection_update(s2)
print(s1)
# Out:
# {4, 5}

# %%
#The intersection() method in set class is similar to its intersection_update() method, 
#except that it returns a new set o
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}
res=s1.intersection(s2)
print(res)
# Out:
# {4, 5}

# %%
s1 = {1,2,3,4,5} #removes common elements
s2 = {4,5,6,7,8}
s3=s1.symmetric_difference(s2)
print(s3)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
#Loop through sets
s1={1,23,45,-78,23,-56,12,96}
for i in s1:
    print(i)
# Out:
# 96
# 1
# -78
# 23
# -56
# 12
# 45

# %%
se1=set()
for i in range(5):
    se1.add(i)
print(se1)
# Out:
# {0, 1, 2, 3, 4}

# %%
#Join sets
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s3 = s1|s2
print (s3)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s3 = s1.union(s2)
print (s3)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s1.update(s2)
print (s1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
#unpacking operator
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s3 = {*s1, *s2}
print (s3)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1={1,2,3}
s2={3,4,5}
join_set={x for s in [s1,s2] for x in s}
print(join_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
#copy
lang1 = {"C", "C++", "Java", "Python"}
print ("lang1: ", lang1, "id(lang1): ", id(lang1))
lang2 = lang1.copy()
print ("lang2: ", lang2, "id(lang2): ", id(lang2))
lang1.add("PHP")
print ("After updating lang1")
print ("lang1: ", lang1, "id(lang1): ", id(lang1))
print ("lang2: ", lang2, "id(lang2): ", id(lang2))
# Out:
# lang1:  {'Java', 'C', 'Python', 'C++'} id(lang1):  1991336354080
# lang2:  {'Java', 'C', 'Python', 'C++'} id(lang2):  1991336273952
# After updating lang1
# lang1:  {'Python', 'C++', 'PHP', 'C', 'Java'} id(lang1):  1991336354080
# lang2:  {'Java', 'C', 'Python', 'C++'} id(lang2):  1991336273952

# %%
original_set = {1, 2, 3, 4}
copied_set = set(original_set)
print("copied set:", copied_set) 
copied_set.add(5)
print("copied set:",copied_set)      
print("original set:",original_set)
# Out:
# copied set: {1, 2, 3, 4}
# copied set: {1, 2, 3, 4, 5}
# original set: {1, 2, 3, 4}

# %%
original_set = {1, 2, 3, 4, 5}
copied_set = {x for x in original_set}
print("Copied set:", copied_set)
# Out:
# Copied set: {1, 2, 3, 4, 5}

# %%
#setoperations
#union
set1 = {1, 2, 3}
set2 = {3, 4, 5}
set3 = {6, 8, 9}
set4 = {9, 45, 73}
union_set1 = set1.union(set2)
union_set2 = set3 | set4
print ('The union of set1 and set2 is', union_set1)
print ('The union of set3 and set4 is', union_set2)
# Out:
# The union of set1 and set2 is {1, 2, 3, 4, 5}
# The union of set3 and set4 is {73, 6, 8, 9, 45}

# %%
#intersection
set1 = {1, 2, 3}
set2 = {3, 4, 5}
set3 = {6, 8, 9}
set4 = {9, 8, 73}
intersection_set1 = set1.intersection(set2)  
intersection_set2 = set3  & set4
print ('The intersection of set1 and set2 is', intersection_set1)
print ('The intersection of set3 and set4 is', intersection_set2)
# Out:
# The intersection of set1 and set2 is {3}
# The intersection of set3 and set4 is {8, 9}

# %%
#difference
set1 = {1, 2, 3}
set2 = {3, 4, 5}
set3 = {6, 8, 9}
set4 = {9, 8, 73}
difference_set1 = set1.difference(set2)
difference_set2 = set3 - set4
print ('The difference between set1 and set2 is', difference_set1)
print ('The difference between set3 and set4 is', difference_set2)
# Out:
# The difference between set1 and set2 is {1, 2}
# The difference between set3 and set4 is {6}

# %%
#symmetric difference
set1 = {1, 2, 3}
set2 = {3, 4, 5}
set3 = {6, 8, 9}
set4 = {9, 8, 73}
symmetric_difference_set1 = set1.symmetric_difference(set2)  
symmetric_difference_set2 = set3 ^ set4
print ('The symmetric difference of set1 and set2 is', symmetric_difference_set1)
print ('The symmetric difference of set3 and set4 is', symmetric_difference_set2)
# Out:
# The symmetric difference of set1 and set2 is {1, 2, 4, 5}
# The symmetric difference of set3 and set4 is {73, 6}

# %%
#subset
set1 = {1, 2}
set2 = {1, 2, 3, 4}
set3 = {64, 47, 245, 48}
set4 = {64, 47, 3}
is_subset1 = set1.issubset(set2)  
is_subset2 = set3 <= set4
print ('set1 is a subset of set2:', is_subset1)
print ('set3 is a subset of set4:', is_subset2)
# Out:
# set1 is a subset of set2: True
# set3 is a subset of set4: False
